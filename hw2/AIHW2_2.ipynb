# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianWengier/CAP4630/blob/master/hw2/AIHW2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt
import numpy as np

fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# Underfit Model:

# %%
# set up the layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(1, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 20
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)

history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc_values = history_dict['acc']
test_acc_values = history_dict['val_acc']

plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs_range, test_acc_values, 'ro', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 88us/sample - loss: 1.9065 - acc: 0.2261 - val_loss: 1.7019 - val_acc: 0.2753
# Epoch 2/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 1.6144 - acc: 0.3178 - val_loss: 1.5655 - val_acc: 0.3454
# Epoch 3/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 1.5193 - acc: 0.3885 - val_loss: 1.4983 - val_acc: 0.4023
# Epoch 4/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 1.4687 - acc: 0.4091 - val_loss: 1.4625 - val_acc: 0.4115
# Epoch 5/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 1.4360 - acc: 0.4179 - val_loss: 1.4334 - val_acc: 0.4273
# Epoch 6/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 1.4131 - acc: 0.4276 - val_loss: 1.4134 - val_acc: 0.4237
# Epoch 7/20
# 60000/60000 [==============================] - 4s 74us/sample - loss: 1.3953 - acc: 0.4318 - val_loss: 1.3996 - val_acc: 0.4370
# Epoch 8/20
# 60000/60000 [==============================] - 6s 93us/sample - loss: 1.3813 - acc: 0.4381 - val_loss: 1.3880 - val_acc: 0.4333
# Epoch 9/20
# 60000/60000 [==============================] - 5s 91us/sample - loss: 1.3697 - acc: 0.4402 - val_loss: 1.3816 - val_acc: 0.4409
# Epoch 10/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 1.3605 - acc: 0.4438 - val_loss: 1.3719 - val_acc: 0.4462
# Epoch 11/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 1.3517 - acc: 0.4477 - val_loss: 1.3654 - val_acc: 0.4531
# Epoch 12/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 1.3451 - acc: 0.4506 - val_loss: 1.3681 - val_acc: 0.4489
# Epoch 13/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 1.3398 - acc: 0.4516 - val_loss: 1.3547 - val_acc: 0.4444
# Epoch 14/20
# 60000/60000 [==============================] - 4s 72us/sample - loss: 1.3342 - acc: 0.4552 - val_loss: 1.3484 - val_acc: 0.4570
# Epoch 15/20
# 60000/60000 [==============================] - 4s 73us/sample - loss: 1.3297 - acc: 0.4567 - val_loss: 1.3459 - val_acc: 0.4629
# Epoch 16/20
# 60000/60000 [==============================] - 4s 71us/sample - loss: 1.3261 - acc: 0.4573 - val_loss: 1.3434 - val_acc: 0.4644
# Epoch 17/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 1.3215 - acc: 0.4606 - val_loss: 1.3408 - val_acc: 0.4557
# Epoch 18/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 1.3185 - acc: 0.4606 - val_loss: 1.3385 - val_acc: 0.4527
# Epoch 19/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 1.3152 - acc: 0.4620 - val_loss: 1.3431 - val_acc: 0.4562
# Epoch 20/20
# 60000/60000 [==============================] - 5s 75us/sample - loss: 1.3126 - acc: 0.4624 - val_loss: 1.3373 - val_acc: 0.4589
# 10000/10000 [==============================] - 0s 45us/sample - loss: 1.3373 - acc: 0.4589
# Test accuracy: 0.4589

# %% [markdown]
# Overfit Model:

# %%
# set up the layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 20
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)

history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc_values = history_dict['acc']
test_acc_values = history_dict['val_acc']

plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs_range, test_acc_values, 'ro', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 13s 214us/sample - loss: 0.5164 - acc: 0.8120 - val_loss: 0.4220 - val_acc: 0.8480
# Epoch 2/20
# 60000/60000 [==============================] - 13s 213us/sample - loss: 0.3881 - acc: 0.8587 - val_loss: 0.3999 - val_acc: 0.8619
# Epoch 3/20
# 60000/60000 [==============================] - 11s 188us/sample - loss: 0.3507 - acc: 0.8726 - val_loss: 0.3742 - val_acc: 0.8679
# Epoch 4/20
# 60000/60000 [==============================] - 11s 183us/sample - loss: 0.3300 - acc: 0.8800 - val_loss: 0.3648 - val_acc: 0.8699
# Epoch 5/20
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.3131 - acc: 0.8857 - val_loss: 0.3532 - val_acc: 0.8759
# Epoch 6/20
# 60000/60000 [==============================] - 11s 181us/sample - loss: 0.2970 - acc: 0.8910 - val_loss: 0.3886 - val_acc: 0.8632
# Epoch 7/20
# 60000/60000 [==============================] - 11s 178us/sample - loss: 0.2869 - acc: 0.8949 - val_loss: 0.3788 - val_acc: 0.8755
# Epoch 8/20
# 60000/60000 [==============================] - 12s 198us/sample - loss: 0.2760 - acc: 0.8980 - val_loss: 0.3367 - val_acc: 0.8799
# Epoch 9/20
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.2649 - acc: 0.9028 - val_loss: 0.3442 - val_acc: 0.8816
# Epoch 10/20
# 60000/60000 [==============================] - 12s 205us/sample - loss: 0.2572 - acc: 0.9045 - val_loss: 0.3585 - val_acc: 0.8765
# Epoch 11/20
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.2490 - acc: 0.9075 - val_loss: 0.3326 - val_acc: 0.8847
# Epoch 12/20
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.2436 - acc: 0.9101 - val_loss: 0.3659 - val_acc: 0.8775
# Epoch 13/20
# 60000/60000 [==============================] - 12s 193us/sample - loss: 0.2369 - acc: 0.9118 - val_loss: 0.3768 - val_acc: 0.8763
# Epoch 14/20
# 60000/60000 [==============================] - 12s 192us/sample - loss: 0.2306 - acc: 0.9146 - val_loss: 0.3423 - val_acc: 0.8850
# Epoch 15/20
# 60000/60000 [==============================] - 12s 195us/sample - loss: 0.2249 - acc: 0.9155 - val_loss: 0.3499 - val_acc: 0.8828
# Epoch 16/20
# 60000/60000 [==============================] - 12s 197us/sample - loss: 0.2202 - acc: 0.9170 - val_loss: 0.3506 - val_acc: 0.8918
# Epoch 17/20
# 60000/60000 [==============================] - 11s 179us/sample - loss: 0.2157 - acc: 0.9196 - val_loss: 0.3665 - val_acc: 0.8850
# Epoch 18/20
# 60000/60000 [==============================] - 12s 192us/sample - loss: 0.2111 - acc: 0.9199 - val_loss: 0.3793 - val_acc: 0.8816
# Epoch 19/20
# 60000/60000 [==============================] - 11s 187us/sample - loss: 0.2055 - acc: 0.9231 - val_loss: 0.4168 - val_acc: 0.8814
# Epoch 20/20
# 60000/60000 [==============================] - 12s 206us/sample - loss: 0.2036 - acc: 0.9241 - val_loss: 0.3688 - val_acc: 0.8884
# 10000/10000 [==============================] - 1s 79us/sample - loss: 0.3688 - acc: 0.8884
# Test accuracy: 0.8884

# %% [markdown]
# Okay Model:

# %%
# set up the layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])

# compile the model

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# train the model
epochs = 20
history = model.fit(train_images, 
                      train_labels, 
                      epochs=epochs,  
                      validation_data=(test_images, test_labels))

test_loss, test_acc = model.evaluate(test_images, test_labels)
print('Test accuracy:', test_acc)

history_dict = history.history
loss_values = history_dict['loss']
test_loss_values = history_dict['val_loss']
epochs_range = range(1, epochs+1)

plt.plot(epochs_range, loss_values, 'bo', label='Training loss')
plt.plot(epochs_range, test_loss_values, 'ro', label='Test loss')
plt.title('Training and test loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc_values = history_dict['acc']
test_acc_values = history_dict['val_acc']

plt.plot(epochs_range, acc_values, 'bo', label='Training accuracy')
plt.plot(epochs_range, test_acc_values, 'ro', label='Test accuracy')
plt.title('Training and test accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.6701 - acc: 0.7576 - val_loss: 0.4533 - val_acc: 0.8384
# Epoch 2/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.4779 - acc: 0.8306 - val_loss: 0.4203 - val_acc: 0.8485
# Epoch 3/20
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.4396 - acc: 0.8433 - val_loss: 0.4194 - val_acc: 0.8394
# Epoch 4/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.4214 - acc: 0.8496 - val_loss: 0.3958 - val_acc: 0.8559
# Epoch 5/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.4006 - acc: 0.8553 - val_loss: 0.3792 - val_acc: 0.8630
# Epoch 6/20
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3913 - acc: 0.8600 - val_loss: 0.3803 - val_acc: 0.8608
# Epoch 7/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3815 - acc: 0.8639 - val_loss: 0.3663 - val_acc: 0.8702
# Epoch 8/20
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.3705 - acc: 0.8658 - val_loss: 0.3754 - val_acc: 0.8617
# Epoch 9/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3669 - acc: 0.8678 - val_loss: 0.3688 - val_acc: 0.8678
# Epoch 10/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3604 - acc: 0.8697 - val_loss: 0.3595 - val_acc: 0.8710
# Epoch 11/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3573 - acc: 0.8711 - val_loss: 0.3595 - val_acc: 0.8705
# Epoch 12/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3527 - acc: 0.8730 - val_loss: 0.3581 - val_acc: 0.8702
# Epoch 13/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3467 - acc: 0.8737 - val_loss: 0.3558 - val_acc: 0.8732
# Epoch 14/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3399 - acc: 0.8756 - val_loss: 0.3698 - val_acc: 0.8681
# Epoch 15/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3397 - acc: 0.8763 - val_loss: 0.3511 - val_acc: 0.8750
# Epoch 16/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3320 - acc: 0.8780 - val_loss: 0.3520 - val_acc: 0.8752
# Epoch 17/20
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3359 - acc: 0.8776 - val_loss: 0.3538 - val_acc: 0.8726
# Epoch 18/20
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.3305 - acc: 0.8801 - val_loss: 0.3642 - val_acc: 0.8756
# Epoch 19/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3286 - acc: 0.8807 - val_loss: 0.3503 - val_acc: 0.8795
# Epoch 20/20
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.3280 - acc: 0.8804 - val_loss: 0.3528 - val_acc: 0.8739
# 10000/10000 [==============================] - 0s 29us/sample - loss: 0.3528 - acc: 0.8739
# Test accuracy: 0.8739
